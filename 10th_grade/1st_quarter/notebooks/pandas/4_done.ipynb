# %% [markdown]
# # Filtering and Sorting Data

# %% [markdown]
# ### Шаг 1. Импортируйте необходимые библиотеки

# %%
import pandas as pd

# %% [markdown]
# ### Шаг 2. Импортируйте датасет [отсюда](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv).

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')

# %% [markdown]
# ### Шаг 3. Сохраните его в переменную euro12.

# %%
euro12 = df

# %% [markdown]
# ### Шаг 4. Выберите только колонку Goal

# %%
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ### Шаг 5. Сколько команд участвовали в Euro2012?

# %%
euro12.Team.unique().shape[0]
# Out:
# 16

# %% [markdown]
# ### Шаг 6. Сколько колонок в датасете?

# %%
euro12.shape[1]
# Out:
# 35

# %% [markdown]
# ### Шаг 7. Возьмите колонки Team, Yellow Cards and Red Cards и сохраните их в датафрейм discipline

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### Шаг 8. Отсортируйте датафрейм по двум колонкам: Yellow cards и Red Cards

# %%
euro12.sort_values(by=['Yellow Cards', 'Red Cards'])
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 2               Denmark      4               10                10
# 5               Germany     10               32                32
# 3               England      5               11                18
# 8           Netherlands      2               12                36
# 15              Ukraine      2                7                26
# 4                France      3               22                24
# 12               Russia      5                9                31
# 11  Republic of Ireland      1                7                12
# 1        Czech Republic      4               13                18
# 14               Sweden      5               17                19
# 9                Poland      2               15                23
# 0               Croatia      4               13                12
# 6                Greece      5                8                18
# ...

# %% [markdown]
# ### Шаг 9. Посчитайте среднее количество жёлтых карточек выданных каждой команде

# %%
euro12['Yellow Cards'].mean()
# Out:
# 7.4375

# %% [markdown]
# ### Шаг 10. Найдите команды, набравшие не менее 6 очков

# %%
euro12.loc[euro12.Goals >= 6]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5    Germany     10               32                32             47.8%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 13     Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# ...

# %% [markdown]
# ### Шаг 11. Выберите команды, название которых начинается на G

# %%
euro12.loc[euro12.Team.str[0] == 'G']
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Шаг 12. Выберите первые 7 колонок

# %%
euro12.iloc[:, : 7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Шаг 13. Выберите все колонки кроме последних трёх

# %%
df.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Шагtep 14. Выведите Shooting Accuracy для следующих стран: England, Italy and Russia

# %%
euro12[euro12.Team.isin(['England', 'Italy', 'Russia'])]['Shooting Accuracy']
# Out:
# 3     50.0%
# 7     43.0%
# 12    22.5%
# Name: Shooting Accuracy, dtype: object
